# %% [markdown]
# # Video Processing Pipeline
#
# This notebook processes FishEye Collaborative videos to:
# 1. Extract audio as WAV files
# 2. Detect red boxes around audio detections in the spectrogram
# 3. Extract timestamps and save to CSV

# %% [markdown]
# ## Import Libraries

# %%
# !pip install -U numpy pandas opencv-python matplotlib
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (2.2.6)
# Collecting numpy
#   Using cached numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (4.10.0)
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (3.9.1.post1)
# Collecting matplotlib
#   Using cached matplotlib-3.10.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/fish/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Using cached matplotlib-3.10.7-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
# Installing collected packages: opencv-python, matplotlib
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0
# error: uninstall-no-record-file
#
# × Cannot uninstall opencv-python 4.10.0
# ╰─> The package's contents are unknown: no RECORD file was found for opencv-python.
#
# hint: The package was installed by conda. You should check if it can uninstall the package.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [opencv-python]

# %%
import cv2
import pandas as pd
import numpy as np
from pathlib import Path
import subprocess
import os

# %% [markdown]
# ## Function: Process Video and Extract Timestamps

# %%
def detect_white_line_and_red_box(frame, spectrogram_roi=None):
    """
    Detect when the white vertical line intersects with red detection boxes in the spectrogram
    
    Args:
        frame: BGR image from video
        spectrogram_roi: (x, y, w, h) tuple for spectrogram region, or None for bottom area
    
    Returns:
        bool: True if white line is intersecting a red box, False otherwise
    """
    # Define spectrogram region (bottom portion of video where waveform is)
    if spectrogram_roi:
        x, y, w, h = spectrogram_roi
        roi = frame[y:y+h, x:x+w]
    else:
        # Default: bottom 20% of frame (where spectrogram typically is)
        height = frame.shape[0]
        roi = frame[int(height * 0.8):, :]
    
    roi_height, roi_width = roi.shape[:2]
    
    # Step 1: Find the white vertical line
    # Convert to grayscale for white line detection
    gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    
    # Detect bright vertical structures (the white line)
    # Look for very bright pixels (white line should be near 255)
    _, white_mask = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY)
    
    # Sum along vertical axis to find the x-position with most white pixels
    vertical_profile = np.sum(white_mask, axis=0)
    
    # Find the x-position of the white line (peak in the profile)
    if np.max(vertical_profile) < roi_height * 0.3:  # Threshold: line should span at least 30% of height
        return False  # No clear white line detected
    
    white_line_x = np.argmax(vertical_profile)
    
    # Step 2: Detect red boxes at or near the white line position
    # Convert to HSV for red detection
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)
    
    # Define red color range in HSV (for the red boxes)
    lower_red1 = np.array([0, 100, 100])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])
    
    # Create masks for red color
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    red_mask = cv2.bitwise_or(mask1, mask2)
    
    # Step 3: Check if there are red pixels near the white line position
    # Define a narrow region around the white line (±10 pixels)
    search_width = 10
    left_bound = max(0, white_line_x - search_width)
    right_bound = min(roi_width, white_line_x + search_width)
    
    # Extract the region around the white line
    line_region = red_mask[:, left_bound:right_bound]
    
    # Count red pixels in this region
    red_pixel_count = cv2.countNonZero(line_region)
    
    # If there are enough red pixels near the white line, it's a detection
    # Adjust threshold as needed (currently 100 pixels)
    return red_pixel_count > 100

# %% [markdown]
# ## Function: Detect White Line Intersecting Red Boxes

# %%
def extract_audio(video_path, output_path):
    """
    Extract audio from video file and save as WAV
    Uses ffmpeg via subprocess
    """
    cmd = [
        'ffmpeg',
        '-i', str(video_path),
        '-vn',  # No video
        '-acodec', 'pcm_s16le',  # PCM 16-bit little-endian
        '-ar', '44100',  # Sample rate 44.1kHz
        '-ac', '2',  # Stereo
        '-y',  # Overwrite output file
        str(output_path)
    ]
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True)
        if result.returncode == 0:
            print(f"✓ Extracted audio: {output_path.name}")
            return True
        else:
            print(f"✗ Error extracting {video_path.name}: {result.stderr}")
            return False
    except Exception as e:
        print(f"✗ Exception: {e}")
        return False

# %% [markdown]
# ## Function: Extract Audio from Video

# %%
# Set up paths
video_dir = Path("/Users/wendycao/fish/fisheye")   # root directory
output_audio_dir = Path("/Users/wendycao/fish/fisheye/audio_output")
output_csv_dir = Path("/Users/wendycao/fish/fisheye/detection_timestamps")

# Create output directories
output_audio_dir.mkdir(exist_ok=True)
output_csv_dir.mkdir(exist_ok=True)

# Recursively get all video files in all species subfolders
video_files = sorted(video_dir.rglob("*.mp4"))

print(f"Found {len(video_files)} video files:")
for vf in video_files:
    # Show path relative to project root for clarity
    print(f"  - {vf.relative_to(video_dir)}")
# Out:
# Found 312 video files:
#   - Abudefduf saxatilis/FEC-00136 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00136 Abudefduf saxatilis_cropped.mp4
#   - Abudefduf saxatilis/FEC-00137 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00137 Abudefduf saxatilis_cropped.mp4
#   - Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis_cropped.mp4
#   - Abudefduf saxatilis/FEC-00139 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00139 Abudefduf saxatilis_cropped.mp4
#   - Abudefduf saxatilis/FEC-00140 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00140 Abudefduf saxatilis_cropped.mp4
#   - Acanthurus coeruleus/FEC-00006 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00006 Acanthurus coeruleus_cropped.mp4
#   - Acanthurus coeruleus/FEC-00007 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00007 Acanthurus coeruleus_cropped.mp4
#   - Acanthurus coeruleus/FEC-00008 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00008 Acanthurus coeruleus_cropped.mp4
#   - Acanthurus coeruleus/FEC-00009 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00009 Acanthurus coeruleus_cropped.mp4
#   - Acanthurus coeruleus/FEC-00010 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00010 Acanthurus coeruleus_cropped.mp4
#   - Acanthurus tractus/FEC-00011 Acanthurus tractus.mp4
#   - Acanthurus tractus/FEC-00011 Acanthurus tractus_cropped.mp4
#   - Acanthurus tractus/FEC-00012 Acanthurus tractus.mp4
#   - Acanthurus tractus/FEC-00012 Acanthurus tractus_cropped.mp4
#   - Anisotremus virginicus/FEC-00103 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00103 Anisotremus virginicus_cropped.mp4
#   - Anisotremus virginicus/FEC-00104 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00104 Anisotremus virginicus_cropped.mp4
#   - Anisotremus virginicus/FEC-00105 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00105 Anisotremus virginicus_cropped.mp4
#   - Anisotremus virginicus/FEC-00106 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-
Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00087 Stegastes diencaeus_cropped.mp4
#   - Stegastes diencaeus/FEC-00088 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00088 Stegastes diencaeus_cropped.mp4
#   - Stegastes diencaeus/FEC-00089 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00089 Stegastes diencaeus_cropped.mp4
#   - Stegastes diencaeus/FEC-00090 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00090 Stegastes diencaeus_cropped.mp4
#   - Stegastes diencaeus/FEC-00091 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00091 Stegastes diencaeus_cropped.mp4
#   - Stegastes partitus/FEC-00092 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00092 Stegastes partitus_cropped.mp4
#   - Stegastes partitus/FEC-00093 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00093 Stegastes partitus_cropped.mp4
#   - Stegastes partitus/FEC-00094 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00094 Stegastes partitus_cropped.mp4
#   - Stegastes partitus/FEC-00095 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00095 Stegastes partitus_cropped.mp4
#   - Stegastes partitus/FEC-00096 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00096 Stegastes partitus_cropped.mp4
#   - Stegastes planifrons/FEC-00097 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00097 Stegastes planifrons_cropped.mp4
#   - Stegastes planifrons/FEC-00098 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00098 Stegastes planifrons_cropped.mp4
#   - Stegastes planifrons/FEC-00099 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00099 Stegastes planifrons_cropped.mp4
#   - Stegastes planifrons/FEC-00100 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00100 Stegastes planifrons_cropped.mp4
#   - Stegastes planifrons/FEC-00101 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00101 Stegastes planifrons_cropped.mp4
#   - Thalassoma bifasciatum/FEC-000102 Thalassoma bifasciatum.mp4
#   - Thalassoma bifasciatum/FEC-000102 Thalassoma bifasciatum_cropped.mp4
#   - Thalassoma bifasciatum/FEC-00124 Thalassoma bifasciatum.mp4
#   - Thalassoma bifasciatum/FEC-00124 Thalassoma bifasciatum_cropped.mp4
#   - Thalassoma bifasciatum/FEC-00125 Thalassoma bifasciatum.mp4
#   - Thalassoma bifasciatum/FEC-00125 Thalassoma bifasciatum_cropped.mp4

# %%
video_files = sorted([
    vf for vf in video_dir.rglob("*.mp4")
    if "_cropped" not in vf.stem  # exclude cropped versions
])

print(f"Found {len(video_files)} non-cropped video files:")
for vf in video_files:
    print(f"  - {vf.relative_to(video_dir)}")
# Out:
# Found 156 non-cropped video files:
#   - Abudefduf saxatilis/FEC-00136 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00137 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00139 Abudefduf saxatilis.mp4
#   - Abudefduf saxatilis/FEC-00140 Abudefduf saxatilis.mp4
#   - Acanthurus coeruleus/FEC-00006 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00007 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00008 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00009 Acanthurus coeruleus.mp4
#   - Acanthurus coeruleus/FEC-00010 Acanthurus coeruleus.mp4
#   - Acanthurus tractus/FEC-00011 Acanthurus tractus.mp4
#   - Acanthurus tractus/FEC-00012 Acanthurus tractus.mp4
#   - Anisotremus virginicus/FEC-00103 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00104 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00105 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00106 Anisotremus virginicus.mp4
#   - Anisotremus virginicus/FEC-00107 Anisotremus virginicus.mp4
#   - Aulostomus maculatus/FEC-00013 Aulostomus maculatus.mp4
#   - Aulostomus maculatus/FEC-00014 Aulostomus maculatus.mp4
#   - Aulostomus maculatus/FEC-00015 Aulostomus maculatus.mp4
#   - Azurina cyanea/FEC-00016 Azurina cyanea.mp4
#   - Azurina cyanea/FEC-00017 Azurina cyanea.mp4
#   - Azurina cyanea/FEC-00018 Azurina cyanea.mp4
#   - Azurina multilineata/FEC-00019 Azurina multilineata.mp4
#   - Azurina multilineata/FEC-
Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00088 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00089 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00090 Stegastes diencaeus.mp4
#   - Stegastes diencaeus/FEC-00091 Stegastes diencaeus.mp4
#   - Stegastes partitus/FEC-00092 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00093 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00094 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00095 Stegastes partitus.mp4
#   - Stegastes partitus/FEC-00096 Stegastes partitus.mp4
#   - Stegastes planifrons/FEC-00097 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00098 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00099 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00100 Stegastes planifrons.mp4
#   - Stegastes planifrons/FEC-00101 Stegastes planifrons.mp4
#   - Thalassoma bifasciatum/FEC-000102 Thalassoma bifasciatum.mp4
#   - Thalassoma bifasciatum/FEC-00124 Thalassoma bifasciatum.mp4
#   - Thalassoma bifasciatum/FEC-00125 Thalassoma bifasciatum.mp4

# %% [markdown]
# ## Process All Videos

# %%
def extract_detection_timestamps(video_path, spectrogram_roi=None):
    """
    Process video and extract time intervals when white line crosses red detection boxes.
    
    Returns:
        list of (float, float): [(start_time_1, end_time_1), (start_time_2, end_time_2), ...]
        Times are in seconds.
    """
    cap = cv2.VideoCapture(str(video_path))
    fps = cap.get(cv2.CAP_PROP_FPS)

    detection_intervals = []
    was_detecting = False
    detection_start_frame = None

    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        has_detection = detect_white_line_and_red_box(frame, spectrogram_roi)

        if has_detection:
            if not was_detecting:
                # Start of new detection event
                detection_start_frame = frame_count
                was_detecting = True
        else:
            if was_detecting:
                # End of detection - record start and end timestamps
                detection_end_frame = frame_count - 1
                start_time = detection_start_frame / fps
                end_time = detection_end_frame / fps
                detection_intervals.append((start_time, end_time))
                was_detecting = False

        frame_count += 1

    # Handle case where detection extends to end of video
    if was_detecting:
        detection_end_frame = frame_count - 1
        start_time = detection_start_frame / fps
        end_time = detection_end_frame / fps
        detection_intervals.append((start_time, end_time))

    cap.release()
    print(f"  Found {len(detection_intervals)} detection interval(s)")

    return detection_intervals

# %%
import pandas as pd

all_results = []

for video_file in video_files:
    print(f"\nProcessing: {video_file.name}")
    print("=" * 60)
    
    # Step 1: Extract audio
    audio_filename = video_file.stem + ".wav"
    audio_path = output_audio_dir / audio_filename
    extract_audio(video_file, audio_path)
    
    # Step 2: Extract detection intervals
    print(f"Analyzing video for white line intersecting red boxes...")
    detection_intervals = extract_detection_timestamps(video_file)
    
    # Step 3: Store results - one row per detection interval
    for start_time, end_time in detection_intervals:
        # Optional midpoint if you still care about it:
        midpoint = (start_time + end_time) / 2.0
        
        all_results.append({
            'video_file': video_file.name,
            'audio_file': audio_filename,
            'detection_start': start_time,
            'detection_end': end_time,
            # uncomment if you want to keep this for continuity
            # 'detection_midpoint': midpoint,
        })

print("\n" + "=" * 60)
print(f"Processing complete! Total detections: {len(all_results)}")
# Out:
# Processing: FEC-00136 Abudefduf saxatilis.mp4
# ============================================================
# ✓ Extracted audio: FEC-00136 Abudefduf saxatilis.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00137 Abudefduf saxatilis.mp4
# ============================================================
# ✓ Extracted audio: FEC-00137 Abudefduf saxatilis.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00138 Abudefduf saxatilis.mp4
# ============================================================
# ✓ Extracted audio: FEC-
.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00181 Pempheris schomburgkii.mp4
# ============================================================
# ✓ Extracted audio: FEC-00181 Pempheris schomburgkii.wav
# Analyzing video for white line intersecting red boxes...
#   Found 0 detection interval(s)
#
# Processing: FEC-00182 Pempheris schomburgkii.mp4
# ============================================================
# ✓ Extracted audio: FEC-00182 Pempheris schomburgkii.wav
# Analyzing video for white line intersecting red boxes...
#   Found 0 detection interval(s)
#
# Processing: FEC-00183 Pempheris schomburgkii.mp4
# ============================================================
# ✓ Extracted audio: FEC-00183 Pempheris schomburgkii.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00184 Pempheris schomburgkii.mp4
# ============================================================
# ✓ Extracted audio: FEC-00184 Pempheris schomburgkii.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00185 Pempheris schomburgkii.mp4
# ============================================================
# ✓ Extracted audio: FEC-00185 Pempheris schomburgkii.wav
# Analyzing video for white line intersecting red boxes...
#   Found 0 detection interval(s)
#
# Processing: FEC-00065 Scarus iseri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00065 Scarus iseri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00066 Scarus iseri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00066 Scarus iseri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00067 Scarus iseri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00067 Scarus iseri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00068 Scarus iseri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00068 Scarus iseri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00069 Scarus iseri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00069 Scarus iseri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 4 detection interval(s)
#
# Processing: FEC-00070 Scarus taeniopterus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00070 Scarus taeniopterus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00071 Scarus taeniopterus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00071 Scarus taeniopterus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00072 Scarus taeniopterus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00072 Scarus taeniopterus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00073 Scarus taeniopterus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00073 Scarus taeniopterus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 3 detection interval(s)
#
# Processing: FEC-00074 Scarus vetula.mp4
# ============================================================
# ✓ Extracted audio: FEC-00074 Scarus vetula.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00075 Scarus vetula.mp4
# ============================================================
# ✓ Extracted audio: FEC-00075 Scarus vetula.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00076 Sparisoma aurofrenatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00076 Sparisoma aurofrenatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00077 Sparisoma aurofrenatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00077 Sparisoma aurofrenatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00078 Sparisoma aurofrenatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00078 Sparisoma aurofrenatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00079 Sparisoma aurofrenatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00079 Sparisoma aurofrenatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00080 Sparisoma aurofrenatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00080 Sparisoma aurofrenatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 3 detection interval(s)
#
# Processing: FEC-00081 Sparisoma rubripinne.mp4
# ============================================================
# ✓ Extracted audio: FEC-00081 Sparisoma rubripinne.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00190 Sparisoma rubripinne.mp4
# ============================================================
# ✓ Extracted audio: FEC-00190 Sparisoma rubripinne.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00082 Sparisoma viride.mp4
# ============================================================
# ✓ Extracted audio: FEC-00082 Sparisoma viride.wav
# Analyzing video for white line intersecting red boxes...
#   Found 5 detection interval(s)
#
# Processing: FEC-00083 Sparisoma viride.mp4
# ============================================================
# ✓ Extracted audio: FEC-00083 Sparisoma viride.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00084 Sparisoma viride.mp4
# ============================================================
# ✓ Extracted audio: FEC-00084 Sparisoma viride.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00085 Sparisoma viride.mp4
# ============================================================
# ✓ Extracted audio: FEC-00085 Sparisoma viride.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00086 Sphoeroides spengleri.mp4
# ============================================================
# ✓ Extracted audio: FEC-00086 Sphoeroides spengleri.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00087 Stegastes diencaeus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00087 Stegastes diencaeus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00088 Stegastes diencaeus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00088 Stegastes diencaeus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00089 Stegastes diencaeus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00089 Stegastes diencaeus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00090 Stegastes diencaeus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00090 Stegastes diencaeus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00091 Stegastes diencaeus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00091 Stegastes diencaeus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00092 Stegastes partitus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00092 Stegastes partitus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00093 Stegastes partitus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00093 Stegastes partitus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00094 Stegastes partitus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00094 Stegastes partitus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 3 detection interval(s)
#
# Processing: FEC-00095 Stegastes partitus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00095 Stegastes partitus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00096 Stegastes partitus.mp4
# ============================================================
# ✓ Extracted audio: FEC-00096 Stegastes partitus.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00097 Stegastes planifrons.mp4
# ============================================================
# ✓ Extracted audio: FEC-00097 Stegastes planifrons.wav
# Analyzing video for white line intersecting red boxes...
#   Found 3 detection interval(s)
#
# Processing: FEC-00098 Stegastes planifrons.mp4
# ============================================================
# ✓ Extracted audio: FEC-00098 Stegastes planifrons.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00099 Stegastes planifrons.mp4
# ============================================================
# ✓ Extracted audio: FEC-00099 Stegastes planifrons.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00100 Stegastes planifrons.mp4
# ============================================================
# ✓ Extracted audio: FEC-00100 Stegastes planifrons.wav
# Analyzing video for white line intersecting red boxes...
#   Found 2 detection interval(s)
#
# Processing: FEC-00101 Stegastes planifrons.mp4
# ============================================================
# ✓ Extracted audio: FEC-00101 Stegastes planifrons.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-000102 Thalassoma bifasciatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-000102 Thalassoma bifasciatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00124 Thalassoma bifasciatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00124 Thalassoma bifasciatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# Processing: FEC-00125 Thalassoma bifasciatum.mp4
# ============================================================
# ✓ Extracted audio: FEC-00125 Thalassoma bifasciatum.wav
# Analyzing video for white line intersecting red boxes...
#   Found 1 detection interval(s)
#
# ============================================================
# Processing complete! Total detections: 265

# %%
# Save to CSV
df = pd.DataFrame(all_results)
csv_path = output_csv_dir / "detection_timestamps.csv"
df.to_csv(csv_path, index=False)

print(f"\n✓ Results saved to: {csv_path}")

print("\nSummary - First 10 detections:")
print(df.head(10))

print(f"\nTotal detections across all videos: {len(df)}")
# Out:
# ✓ Results saved to: /Users/wendycao/fish/fisheye/detection_timestamps/detection_timestamps.csv
#
# Summary - First 10 detections:
#                            video_file                          audio_file  \
# 0   FEC-00136 Abudefduf saxatilis.mp4   FEC-00136 Abudefduf saxatilis.wav
# 1   FEC-00137 Abudefduf saxatilis.mp4   FEC-00137 Abudefduf saxatilis.wav
# 2   FEC-00138 Abudefduf saxatilis.mp4   FEC-00138 Abudefduf saxatilis.wav
# 3   FEC-00138 Abudefduf saxatilis.mp4   FEC-00138 Abudefduf saxatilis.wav
# 4   FEC-00138 Abudefduf saxatilis.mp4   FEC-00138 Abudefduf saxatilis.wav
# 5   FEC-00138 Abudefduf saxatilis.mp4   FEC-00138 Abudefduf saxatilis.wav
# 6   FEC-00139 Abudefduf saxatilis.mp4   FEC-00139 Abudefduf saxatilis.wav
# 7   FEC-00140 Abudefduf saxatilis.mp4   FEC-00140 Abudefduf saxatilis.wav
# 8  FEC-00006 Acanthurus coeruleus.mp4  FEC-00006 Acanthurus coeruleus.wav
# 9  FEC-00007 Acanthurus coeruleus.mp4  FEC-00007 Acanthurus coeruleus.wav
#
#    detection_start  detection_end
# 0         8.000000       8.166667
# 1         8.000000       8.266667
# 2         5.500000       5.766667
# 3         7.333333       7.833333
# 4         8.600000       8.866667
# 5        10.600000      10.833333
# 6         8.000000       8.233333
# 7         8.000000       8.233333
# 8         8.000000       8.333333
# 9         7.966667       8.133333
#
# Total detections across all videos: 265

# %% [markdown]
# ## Extract audio/video clips

# %%
import ffmpeg
from pathlib import Path

# %%
# Set your project root
root_dir = Path("/Users/wendycao/fish/fisheye")

# Existing folders
audio_output_dir = root_dir / "audio_output"
detection_csv_dir = root_dir / "detection_timestamps"

# Output folders for clips
output_video_clips_dir = root_dir / "video_clips_5s"
output_audio_clips_dir = root_dir / "audio_clips_5s"
output_video_clips_dir.mkdir(exist_ok=True)
output_audio_clips_dir.mkdir(exist_ok=True)

# Load detections CSV
csv_path = detection_csv_dir / "detection_timestamps.csv"
df = pd.read_csv(csv_path)

# %%
def get_media_duration(path: Path) -> float:
    """
    Return media duration in seconds using ffprobe via ffmpeg-python.
    """
    probe = ffmpeg.probe(str(path))
    return float(probe["format"]["duration"])

# %%
def make_5s_detection_video(video_path: Path,
                            center_time: float,
                            out_path: Path,
                            target_len: float = 5.0):
    """
    Create ~5s video clip centered on center_time (clamped to video duration).
    """
    duration = get_media_duration(video_path)

    start = max(0.0, center_time - target_len / 2.0)
    end = min(duration, center_time + target_len / 2.0)
    clip_len = end - start

    if clip_len <= 0:
        print(f"  [WARN] Skipping video: invalid interval ({start:.3f}, {end:.3f})")
        return

    (
        ffmpeg
        .input(str(video_path), ss=start, t=clip_len)
        .output(
            str(out_path),
            vcodec="libx264",
            acodec="aac",
        )
        .overwrite_output()
        .run(quiet=True)
    )

# %%
def make_5s_detection_audio(audio_path: Path,
                            det_start: float,
                            det_end: float,
                            out_path: Path,
                            target_len: float = 5.0):
    """
    Create a 5s WAV where the detected sound is centered in time
    and the rest is silence (using ffmpeg-python).
    """
    audio_duration = get_media_duration(audio_path)

    # Clamp detection interval
    start = max(0.0, det_start)
    end = min(audio_duration, det_end)

    if end <= start:
        print(f"  [WARN] Skipping audio: invalid interval ({start:.3f}, {end:.3f})")
        return

    sound_len = end - start

    # Case 1: detection >= target_len → just take central 5s of detection
    if sound_len >= target_len:
        central_start = start + (sound_len - target_len) / 2.0

        (
            ffmpeg
            .input(str(audio_path), ss=central_start, t=target_len)
            .output(
                str(out_path),
                acodec="pcm_s16le",
                ar=44100,
                ac=1,
            )
            .overwrite_output()
            .run(quiet=True)
        )
        return

    # Case 2: detection < target_len → create 5s silence, overlay detection in middle
    silence_total = target_len - sound_len
    pad_before = silence_total / 2.0
    delay_ms = int(round(pad_before * 1000))

    # 5s silence base
    silence = ffmpeg.input(
        "anullsrc=r=44100:cl=mono",
        f="lavfi",
        t=target_len,
    )

    # Detection segment
    segment = ffmpeg.input(str(audio_path), ss=start, t=sound_len)

    # Delay detection so it starts at pad_before seconds
    delayed = segment.filter("adelay", f"{delay_ms}|{delay_ms}")

    # Mix delayed detection onto silence
    mixed = ffmpeg.filter([silence, delayed], "amix", inputs=2, normalize=0)

    (
        ffmpeg
        .output(
            mixed,
            str(out_path),
            acodec="pcm_s16le",
            ar=44100,
            ac=1,
        )
        .overwrite_output()
        .run(quiet=True)
    )

# %%
# All non-cropped videos under root_dir
video_map = {
    p.name: p
    for p in root_dir.rglob("*.mp4")
    if "_cropped" not in p.stem
}

# All pre-extracted audio files in audio_output
audio_map = {
    p.name: p
    for p in audio_output_dir.glob("*.wav")
}

# %%
def get_species_name(video_path: Path) -> str:
    return video_path.parent.name

# %%
video_det_count = {}

for idx, row in df.iterrows():
    video_name = row["video_file"]
    audio_name = row["audio_file"]

    det_start = float(row["detection_start"])
    det_end = float(row["detection_end"])

    # Compute midpoint (center of detection)
    det_mid = (det_start + det_end) / 2.0

    video_path = video_map.get(video_name)
    audio_path = audio_map.get(audio_name)

    if video_path is None:
        print(f"[WARN] Missing video on disk for: {video_name}")
        continue
    if audio_path is None:
        print(f"[WARN] Missing audio on disk for: {audio_name}")
        continue

    # Species = folder name containing video
    species = get_species_name(video_path)

    # Create species output dirs
    species_video_dir = output_video_clips_dir / species
    species_audio_dir = output_audio_clips_dir / species
    species_video_dir.mkdir(parents=True, exist_ok=True)
    species_audio_dir.mkdir(parents=True, exist_ok=True)

    # Detection index counter per video
    count = video_det_count.get(video_name, 0)
    video_det_count[video_name] = count + 1
    det_id = f"{count:03d}"

    video_out = species_video_dir / f"{video_path.stem}_det{det_id}.mp4"
    audio_out = species_audio_dir / f"{audio_path.stem}_det{det_id}.wav"

    print(f"\nDetection {idx} | {species} | {video_name}")
    print(f"  start={det_start:.3f}, end={det_end:.3f}, mid={det_mid:.3f}")

    # Create clips
    make_5s_detection_video(video_path, det_mid, video_out)
    make_5s_detection_audio(audio_path, det_start, det_end, audio_out)

print("\n✓ Finished exporting all 5-second clips into species folders.")
# Out:
# Detection 0 | Abudefduf saxatilis | FEC-00136 Abudefduf saxatilis.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 1 | Abudefduf saxatilis | FEC-00137 Abudefduf saxatilis.mp4
#   start=8.000, end=8.267, mid=8.133
#
# Detection 2 | Abudefduf saxatilis | FEC-00138 Abudefduf saxatilis.mp4
#   start=5.500, end=5.767, mid=5.633
#
# Detection 3 | Abudefduf saxatilis | FEC-00138 Abudefduf saxatilis.mp4
#   start=7.333, end=7.833, mid=7.583
#
# Detection 4 | Abudefduf saxatilis | FEC-00138 Abudefduf saxatilis.mp4
#   start=8.600, end=8.867, mid=8.733
#
# Detection 5 | Abudefduf saxatilis | FEC-00138 Abudefduf saxatilis.mp4
#   start=10.600, end=10.833, mid=10.717
#
# Detection 6 | Abudefduf saxatilis | FEC-00139 Abudefduf saxatilis.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 7 | Abudefduf saxatilis | FEC-00140 Abudefduf saxatilis.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 8 | Acanthurus coeruleus | FEC-00006 Acanthurus coeruleus.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 9 | Acanthurus coeruleus | FEC-00007 Acanthurus coeruleus.mp4
#   start=7.967, end=8.133, mid=8.050
#
# Detection 10 | Acanthurus coeruleus | FEC-00008 Acanthurus coeruleus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 11 | Acanthurus coeruleus | FEC-00009 Acanthurus coeruleus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 12 | Acanthurus coeruleus | FEC-00010 Acanthurus coeruleus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 13 | Acanthurus tractus | FEC-00011 Acanthurus tractus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 14 | Acanthurus tractus | FEC-00012 Acanthurus tractus.mp4
#   start=7.967, end=7.967, mid=7.967
#   [WARN] Skipping audio: invalid interval (7.967, 7.967)
#
# Detection 15 | Acanthurus tractus | FEC-00012 Acanthurus tractus.mp4
#   start=8.033, end=8.233, mid=8.133
#
# Detection 16 | Acanthurus tractus | FEC-00012 Acanthurus tractus.mp4
#   start=8.300, end=8.300, mid=8.300
#   [WARN] Skipping audio: invalid interval (8.300, 8.300)
#
# Detection 17 | Anisotremus virginicus | FEC-00103 Anisotremus virginicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 18 | Anisotremus virginicus | FEC-00104 Anisotremus virginicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 19 | Anisotremus virginicus | FEC-00105 Anisotremus virginicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 20 | Anisotremus virginicus | FEC-00106 Anisotremus virginicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 21 | Anisotremus virginicus | FEC-00107 Anisotremus virginicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 22 | Aulostomus maculatus | FEC-00013 Aulostomus maculatus.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 23 | Aulostomus maculatus | FEC-00014 Aulostomus maculatus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 24 | Aulostomus maculatus | FEC-00015 Aulostomus maculatus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 25 | Azurina cyanea | FEC-00016 Azurina cyanea.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 26 | Azurina cyanea | FEC-00016 Azurina cyanea.mp4
#   start=8.200, end=8.333, mid=8.267
#
# Detection 27 | Azurina cyanea | FEC-00017 Azurina cyanea.mp4
#   start=6.000, end=6.133, mid=6.067
#
# Detection 28 | Azurina cyanea | FEC-00017 Azurina cyanea.mp4
#   start=8.933, end=9.067, mid=9.000
#
# Detection 29 | Azurina cyanea | FEC-00018 Azurina cyanea.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 30 | Azurina multilineata | FEC-00019 Azurina multilineata.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 31 | Azurina multilineata | FEC-00020 Azurina multilineata.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 32 | Azurina multilineata | FEC-00020 Azurina multilineata.mp4
#   start=8.500, end=8.700, mid=8.600
#
# Detection 33 | Azurina multilineata | FEC-00021 Azurina multilineata.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 34 | Azurina multilineata | FEC-00021 Azurina multilineata.mp4
#   start=8.200, end=8.200, mid=8.200
#   [WARN] Skipping audio: invalid interval (8.200, 8.200)
#
# Detection 35 | Azurina multilineata | FEC-00022 Azurina multilineata.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 36 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=5.733, end=5.767, mid=5.750
#
# Detection 37 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=6.100, end=6.133, mid=6.117
#
# Detection 38 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=6.900, end=6.933, mid=6.917
#
# Detection 39 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=7.400, end=7.400, mid=7.400
#   [WARN] Skipping audio: invalid interval (7.400, 7.400)
#
# Detection 40 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 41 | Azurina multilineata | FEC-00023 Azurina multilineata.mp4
#   start=8.800, end=8.967, mid=8.883
#
# Detection 42 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=7.000, end=7.000, mid=7.000
#   [WARN] Skipping audio: invalid interval (7.000, 7.000)
#
# Detection 43 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=7.067, end=7.200, mid=7.133
#
# Detection 44 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=7.900, end=7.900, mid=7.900
#   [WARN] Skipping audio: invalid interval (7.900, 7.900)
#
# Detection 45 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=7.967, end=8.100, mid=8.033
#
# Detection 46 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=9.033, end=9.167, mid=9.100
#
# Detection 47 | Bodianus rufus | FEC-00108 Bodianus rufus.mp4
#   start=11.233, end=11.367, mid=11.300
#
# Detection 48 | Brachygenys chrysargyrea | FEC-00024 Brachygenys chrysargyrea.mp4
#   start=7.967, end=8.100, mid=8.033
#
# Detection 49 | Brachygenys chrysargyrea | FEC-00024 Brachygenys chrysargyrea.mp4
#   start=8.333, end=8.533, mid=8.433
#
# Detection 50 | Brachygenys chrysargyrea | FEC-00024 Brachygenys chrysargyrea.mp4
#   start=8.600, end=8.600, mid=8.600
#   [WARN] Skipping audio: invalid interval (8.600, 8.600)
#
# Detection 51 | Canthigaster rostrata | FEC-00025 Canthigaster rostrata.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 52 | Canthigaster rostrata | FEC-00135 Canthigaster rostrata.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 53 | Canthigaster rostrata | FEC-00135 Canthigaster rostrata.mp4
#   start=11.367, end=11.367, mid=11.367
#   [WARN] Skipping audio: invalid interval (11.367, 11.367)
#
# Detection 54 | Canthigaster rostrata | FEC-00135 Canthigaster rostrata.mp4
#   start=11.433, end=11.567, mid=11.500
#
# Detection 55 | Caranx ruber | FEC-00026 Caranx ruber.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 56 | Caranx ruber | FEC-00027 Caranx ruber.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 57 | Caranx ruber | FEC-00028 Caranx ruber.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 58 | Caranx ruber | FEC-00029 Caranx ruber.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 59 | Caranx ruber | FEC-00030 Caranx ruber.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 60 | Caranx ruber | FEC-00030 Caranx ruber.mp4
#   start=8.367, end=8.533, mid=8.450
#
# Detection 61 | Cephalopholis cruentata | FEC-00186 Cephalopholis cruentata.mp4
#   start=7.933, end=8.133, mid=8.033
#
# Detection 62 | Cephalopholis fulva | FEC-00031 Cephalopholis fulva.mp4
#   start=8.000, end=8.667, mid=8.333
#
# Detection 63 | Cephalopholis fulva | FEC-00133 Cephalopholis fulva.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 64 | Chaetodon capistratus | FEC-00109 Chaetodon capistratus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 65 | Chaetodon capistratus | FEC-00109 Chaetodon capistratus.mp4
#   start=8.800, end=8.800, mid=8.800
#   [WARN] Skipping audio: invalid interval (8.800, 8.800)
#
# Detection 66 | Chaetodon capistratus | FEC-00109 Chaetodon capistratus.mp4
#   start=8.867, end=9.000, mid=8.933
#
# Detection 67 | Chaetodon capistratus | FEC-00110 Chaetodon capistratus.mp4
#   start=8.000, end=8.067, mid=8.033
#
# Detection 68 | Chaetodon capistratus | FEC-00110 Chaetodon capistratus.mp4
#   start=8.133, end=8.167, mid=8.150
#
# Detection 69 | Chaetodon capistratus | FEC-00111 Chaetodon capistratus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 70 | Chaetodon capistratus | FEC-00111 Chaetodon capistratus.mp4
#   start=9.133, end=9.300, mid=9.217
#
# Detection 71 | Chaetodon capistratus | FEC-00112 Chaetodon capistratus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 72 | Chaetodon capistratus | FEC-00187 Chaetodon capistratus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 73 | Clepticus parrae | FEC-00032 Clepticus parrae.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 74 | Clepticus parrae | FEC-00032 Clepticus parrae.mp4
#   start=8.567, end=8.733, mid=8.650
#
# Detection 75 | Clepticus parrae | FEC-00034 Clepticus parrae.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 76 | Clepticus parrae | FEC-00035 Clepticus parrae.mp4
#   start=8.000, end=8.267, mid=8.133
#
# Detection 77 | Clepticus parrae | FEC-00036 Clepticus parrae.mp4
#   start=8.000, end=8.200, mid=8.100
#
# Detection 78 | Eques punctatus | FEC-00037 Eques punctatus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 79 | Haemulon flavolineatum | FEC-00038 Haemulon flavolineatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 80 | Haemulon flavolineatum | FEC-00123 Haemulon flavolineatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 81 | Haemulon vittatum | FEC-00113 Haemulon vittatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 82 | Haemulon vittatum | FEC-00114 Haemulon vittatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 83 | Halichoeres garnoti | FEC-00039 Halichoeres garnoti.mp4
#   start=7.967, end=8.133, mid=8.050
#
# Detection 84 | Halichoeres garnoti | FEC-00039 Halichoeres garnoti.mp4
#   start=9.700, end=9.833, mid=9.767
#
# Detection 85 | Halichoeres garnoti | FEC-00040 Halichoeres garnoti.mp4
#   start=6.033, end=6.167, mid=6.100
#
# Detection 86 | Halichoeres garnoti | FEC-00040 Halichoeres garnoti.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 87 | Halichoeres garnoti | FEC-00040 Halichoeres garnoti.mp4
#   start=11.600, end=11.767, mid=11.683
#
# Detection 88 | Halichoeres garnoti | FEC-00041 Halichoeres garnoti.mp4
#   start=7.967, end=8.200, mid=8.083
#
# Detection 89 | Halichoeres garnoti | FEC-00042 Halichoeres garnoti.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 90 | Halichoeres garnoti | FEC-00043 Halichoeres garnoti.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 91 | Halichoeres maculipinna | FEC-00170 Halichoeres maculipinna.mp4
#   start=6.000, end=6.133, mid=6.067
#
# Detection 92 | Halichoeres maculipinna | FEC-00170 Halichoeres maculipinna.mp4
#   start=10.733, end=10.900, mid=10.817
#
# Detection 93 | Halichoeres maculipinna | FEC-00171 Halichoeres maculipinna.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 94 | Halichoeres maculipinna | FEC-00172 Halichoeres maculipinna.mp4
#   start=7.000, end=7.133, mid=7.067
#
# Detection 95 | Halichoeres maculipinna | FEC-00172 Halichoeres maculipinna.mp4
#   start=7.400, end=7.533, mid=7.467
#
# Detection 96 | Halichoeres maculipinna | FEC-00172 Halichoeres maculipinna.mp4
#   start=7.867, end=8.000, mid=7.933
#
# Detection 97 | Halichoeres maculipinna | FEC-00172 Halichoeres maculipinna.mp4
#   start=9.267, end=9.267, mid=9.267
#   [WARN] Skipping audio: invalid interval (9.267, 9.267)
#
# Detection 98 | Halichoeres maculipinna | FEC-00172 Halichoeres maculipinna.mp4
#   start=9.333, end=9.400, mid=9.367
#
# Detection 99 | Halichoeres maculipinna | FEC-00173 Halichoeres maculipinna.mp4
#   start=8.000, end=8.067, mid=8.033
#
# Detection 100 | Halichoeres maculipinna | FEC-00173 Halichoeres maculipinna.mp4
#   start=8.133, end=8.133, mid=8.133
#   [WARN] Skipping audio: invalid interval (8.133, 8.133)
#
# Detection 101 | Halichoeres maculipinna | FEC-00174 Halichoeres maculipinna.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 102 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.100, end=3.100, mid=3.100
#   [WARN] Skipping audio: invalid interval (3.100, 3.100)
#
# Detection 103 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.167, end=3.700, mid=3.433
#
# Detection 104 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.767, end=3.767, mid=3.767
#   [WARN] Skipping audio: invalid interval (3.767, 3.767)
#
# Detection 105 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.833, end=3.833, mid=3.833
#   [WARN] Skipping audio: invalid interval (3.833, 3.833)
#
# Detection 106 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.900, end=3.900, mid=3.900
#   [WARN] Skipping audio: invalid interval (3.900, 3.900)
#
# Detection 107 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=3.967, end=3.967, mid=3.967
#   [WARN] Skipping audio: invalid interval (3.967, 3.967)
#
# Detection 108 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=4.033, end=4.033, mid=4.033
#   [WARN] Skipping audio: invalid interval (4.033, 4.033)
#
# Detection 109 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=4.100, end=4.100, mid=4.100
#   [WARN] Skipping audio: invalid interval (4.100, 4.100)
#
# Detection 110 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=4.167, end=4.967, mid=4.567
#
# Detection 111 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=5.033, end=5.033, mid=5.033
#   [WARN] Skipping audio: invalid interval (5.033, 5.033)
#
# Detection 112 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=5.100, end=5.833, mid=5.467
#
# Detection 113 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=5.900, end=5.967, mid=5.933
#
# Detection 114 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.033, end=6.033, mid=6.033
#   [WARN] Skipping audio: invalid interval (6.033, 6.033)
#
# Detection 115 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.100, end=6.100, mid=6.100
#   [WARN] Skipping audio: invalid interval (6.100, 6.100)
#
# Detection 116 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.167, end=6.767, mid=6.467
#
# Detection 117 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.833, end=6.833, mid=6.833
#   [WARN] Skipping audio: invalid interval (6.833, 6.833)
#
# Detection 118 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.900, end=6.900, mid=6.900
#   [WARN] Skipping audio: invalid interval (6.900, 6.900)
#
# Detection 119 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=6.967, end=6.967, mid=6.967
#   [WARN] Skipping audio: invalid interval (6.967, 6.967)
#
# Detection 120 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=7.033, end=7.033, mid=7.033
#   [WARN] Skipping audio: invalid interval (7.033, 7.033)
#
# Detection 121 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=7.100, end=7.100, mid=7.100
#   [WARN] Skipping audio: invalid interval (7.100, 7.100)
#
# Detection 122 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=7.167, end=7.700, mid=7.433
#
# Detection 123 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=7.767, end=7.833, mid=7.800
#
# Detection 124 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=7.900, end=7.967, mid=7.933
#
# Detection 125 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.033, end=8.033, mid=8.033
#   [WARN] Skipping audio: invalid interval (8.033, 8.033)
#
# Detection 126 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.100, end=8.100, mid=8.100
#   [WARN] Skipping audio: invalid interval (8.100, 8.100)
#
# Detection 127 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.167, end=8.200, mid=8.183
#
# Detection 128 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.267, end=8.333, mid=8.300
#
# Detection 129 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.400, end=8.400, mid=8.400
#   [WARN] Skipping audio: invalid interval (8.400, 8.400)
#
# Detection 130 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.467, end=8.467, mid=8.467
#   [WARN] Skipping audio: invalid interval (8.467, 8.467)
#
# Detection 131 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.533, end=8.600, mid=8.567
#
# Detection 132 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=8.667, end=8.767, mid=8.717
#
# Detection 133 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.000, end=9.000, mid=9.000
#   [WARN] Skipping audio: invalid interval (9.000, 9.000)
#
# Detection 134 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.067, end=9.067, mid=9.067
#   [WARN] Skipping audio: invalid interval (9.067, 9.067)
#
# Detection 135 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.133, end=9.133, mid=9.133
#   [WARN] Skipping audio: invalid interval (9.133, 9.133)
#
# Detection 136 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.533, end=9.533, mid=9.533
#   [WARN] Skipping audio: invalid interval (9.533, 9.533)
#
# Detection 137 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.733, end=9.733, mid=9.733
#   [WARN] Skipping audio: invalid interval (9.733, 9.733)
#
# Detection 138 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.800, end=9.800, mid=9.800
#   [WARN] Skipping audio: invalid interval (9.800, 9.800)
#
# Detection 139 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.867, end=9.867, mid=9.867
#   [WARN] Skipping audio: invalid interval (9.867, 9.867)
#
# Detection 140 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=9.933, end=9.933, mid=9.933
#   [WARN] Skipping audio: invalid interval (9.933, 9.933)
#
# Detection 141 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=10.067, end=10.067, mid=10.067
#   [WARN] Skipping audio: invalid interval (10.067, 10.067)
#
# Detection 142 | Halichoeres radiatus | FEC-00175 Halichoeres radiatus.mp4
#   start=10.133, end=10.133, mid=10.133
#   [WARN] Skipping audio: invalid interval (10.133, 10.133)
#
# Detection 143 | Heteropriacanthus cruentatus | FEC-00044 Heteropriacanthus cruentatus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 144 | Heteropriacanthus cruentatus | FEC-00045 Heteropriacanthus cruentatus.mp4
#   start=7.967, end=8.100, mid=8.033
#
# Detection 145 | Heteropriacanthus cruentatus | FEC-00046 Heteropriacanthus cruentatus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 146 | Heteropriacanthus cruentatus | FEC-00047 Heteropriacanthus cruentatus.mp4
#   start=8.000, end=8.200, mid=8.100
#
# Detection 147 | Heteropriacanthus cruentatus | FEC-00047 Heteropriacanthus cruentatus.mp4
#   start=8.300, end=8.667, mid=8.483
#
# Detection 148 | Heteropriacanthus cruentatus | FEC-00047 Heteropriacanthus cruentatus.mp4
#   start=8.733, end=9.500, mid=9.117
#
# Detection 149 | Heteropriacanthus cruentatus | FEC-00048 Heteropriacanthus cruentatus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 150 | Holacanthus ciliaris | FEC-00176 Holacanthus ciliaris.mp4
#   start=3.067, end=6.700, mid=4.883
#
# Detection 151 | Holacanthus ciliaris | FEC-00188 Holacanthus ciliaris.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 152 | Holocentrus adscensionis | FEC-00178 Holocentrus adscensionis.mp4
#   start=8.000, end=8.467, mid=8.233
#
# Detection 153 | Holocentrus adscensionis | FEC-00179 Holocentrus adscensionis.mp4
#   start=3.067, end=10.800, mid=6.933
#
# Detection 154 | Holocentrus adscensionis | FEC-00179 Holocentrus adscensionis.mp4
#   start=10.867, end=10.900, mid=10.883
#
# Detection 155 | Holocentrus adscensionis | FEC-00180 Holocentrus adscensionis.mp4
#   start=3.067, end=10.767, mid=6.917
#
# Detection 156 | Hypoplectrus chlorurus | FEC-00049 Hypoplectrus chlorurus.mp4
#   start=7.967, end=7.967, mid=7.967
#   [WARN] Skipping audio: invalid interval (7.967, 7.967)
#
# Detection 157 | Hypoplectrus chlorurus | FEC-00049 Hypoplectrus chlorurus.mp4
#   start=8.033, end=8.567, mid=8.300
#
# Detection 158 | Hypoplectrus chlorurus | FEC-00134 Hypoplectrus chlorurus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 159 | Kyphosus bigibbus | FEC-00050 Kyphosus bigibbus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 160 | Kyphosus bigibbus | FEC-00051 Kyphosus bigibbus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 161 | Kyphosus bigibbus | FEC-00189 Kyphosus bigibbus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 162 | Lactophrys triqueter | FEC-00052 Lactophrys triqueter.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 163 | Lactophrys triqueter | FEC-00131 Lactophrys triqueter.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 164 | Lactophrys triqueter | FEC-00132 Lactophrys triqueter.mp4
#   start=4.567, end=4.567, mid=4.567
#   [WARN] Skipping audio: invalid interval (4.567, 4.567)
#
# Detection 165 | Lactophrys triqueter | FEC-00132 Lactophrys triqueter.mp4
#   start=4.633, end=4.767, mid=4.700
#
# Detection 166 | Lactophrys triqueter | FEC-00132 Lactophrys triqueter.mp4
#   start=7.267, end=7.433, mid=7.350
#
# Detection 167 | Lactophrys triqueter | FEC-00132 Lactophrys triqueter.mp4
#   start=10.567, end=10.733, mid=10.650
#
# Detection 168 | Lutjanus apodus | FEC-00115 Lutjanus apodus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 169 | Lutjanus apodus | FEC-00116 Lutjanus apodus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 170 | Lutjanus apodus | FEC-00117 Lutjanus apodus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 171 | Lutjanus apodus | FEC-00118 Lutjanus apodus.mp4
#   start=8.033, end=8.033, mid=8.033
#   [WARN] Skipping audio: invalid interval (8.033, 8.033)
#
# Detection 172 | Lutjanus apodus | FEC-00118 Lutjanus apodus.mp4
#   start=9.133, end=9.133, mid=9.133
#   [WARN] Skipping audio: invalid interval (9.133, 9.133)
#
# Detection 173 | Lutjanus griseus | FEC-00053 Lutjanus griseus.mp4
#   start=7.833, end=8.333, mid=8.083
#
# Detection 174 | Lutjanus griseus | FEC-00053 Lutjanus griseus.mp4
#   start=9.100, end=9.467, mid=9.283
#
# Detection 175 | Lutjanus griseus | FEC-00128 Lutjanus griseus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 176 | Lutjanus griseus | FEC-00129 Lutjanus griseus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 177 | Lutjanus griseus | FEC-00129 Lutjanus griseus.mp4
#   start=10.600, end=10.600, mid=10.600
#   [WARN] Skipping audio: invalid interval (10.600, 10.600)
#
# Detection 178 | Lutjanus griseus | FEC-00129 Lutjanus griseus.mp4
#   start=10.667, end=10.800, mid=10.733
#
# Detection 179 | Lutjanus mahogoni | FEC-00119 Lutjanus mahogoni.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 180 | Lutjanus mahogoni | FEC-00120 Lutjanus mahogoni.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 181 | Lutjanus mahogoni | FEC-00121 Lutjanus mahogoni.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 182 | Lutjanus mahogoni | FEC-00122 Lutjanus mahogoni.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 183 | Microspathodon chrysurus | FEC-00054 Microspathodon chrysurus.mp4
#   start=5.500, end=5.667, mid=5.583
#
# Detection 184 | Microspathodon chrysurus | FEC-00054 Microspathodon chrysurus.mp4
#   start=9.133, end=9.300, mid=9.217
#
# Detection 185 | Microspathodon chrysurus | FEC-00055 Microspathodon chrysurus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 186 | Microspathodon chrysurus | FEC-00056 Microspathodon chrysurus.mp4
#   start=6.967, end=7.133, mid=7.050
#
# Detection 187 | Microspathodon chrysurus | FEC-00056 Microspathodon chrysurus.mp4
#   start=10.600, end=10.767, mid=10.683
#
# Detection 188 | Microspathodon chrysurus | FEC-00057 Microspathodon chrysurus.mp4
#   start=8.000, end=8.100, mid=8.050
#
# Detection 189 | Mulloidichthys martinicus | FEC-00058 Mulloidichthys martinicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 190 | Mulloidichthys martinicus | FEC-00130 Mulloidichthys martinicus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 191 | Myripristis jacobus | FEC-00059 Myripristis jacobus.mp4
#   start=8.000, end=8.433, mid=8.217
#
# Detection 192 | Myripristis jacobus | FEC-00060 Myripristis jacobus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 193 | Myripristis jacobus | FEC-00061 Myripristis jacobus.mp4
#   start=7.967, end=8.867, mid=8.417
#
# Detection 194 | Myripristis jacobus | FEC-00062 Myripristis jacobus.mp4
#   start=8.000, end=8.200, mid=8.100
#
# Detection 195 | Myripristis jacobus | FEC-00063 Myripristis jacobus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 196 | Ocyurus chrysurus | FEC-00064 Ocyurus chrysurus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 197 | Ocyurus chrysurus | FEC-00126 Ocyurus chrysurus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 198 | Ocyurus chrysurus | FEC-00127 Ocyurus chrysurus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 199 | Pempheris schomburgkii | FEC-00183 Pempheris schomburgkii.mp4
#   start=6.067, end=10.033, mid=8.050
#
# Detection 200 | Pempheris schomburgkii | FEC-00184 Pempheris schomburgkii.mp4
#   start=3.633, end=8.867, mid=6.250
#
# Detection 201 | Pempheris schomburgkii | FEC-00184 Pempheris schomburgkii.mp4
#   start=8.933, end=11.533, mid=10.233
#
# Detection 202 | Scarus iseri | FEC-00065 Scarus iseri.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 203 | Scarus iseri | FEC-00066 Scarus iseri.mp4
#   start=5.967, end=7.200, mid=6.583
#
# Detection 204 | Scarus iseri | FEC-00066 Scarus iseri.mp4
#   start=9.833, end=10.400, mid=10.117
#
# Detection 205 | Scarus iseri | FEC-00067 Scarus iseri.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 206 | Scarus iseri | FEC-00068 Scarus iseri.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 207 | Scarus iseri | FEC-00069 Scarus iseri.mp4
#   start=6.967, end=7.100, mid=7.033
#
# Detection 208 | Scarus iseri | FEC-00069 Scarus iseri.mp4
#   start=7.633, end=7.767, mid=7.700
#
# Detection 209 | Scarus iseri | FEC-00069 Scarus iseri.mp4
#   start=8.267, end=8.433, mid=8.350
#
# Detection 210 | Scarus iseri | FEC-00069 Scarus iseri.mp4
#   start=9.300, end=9.433, mid=9.367
#
# Detection 211 | Scarus taeniopterus | FEC-00070 Scarus taeniopterus.mp4
#   start=8.000, end=8.067, mid=8.033
#
# Detection 212 | Scarus taeniopterus | FEC-00070 Scarus taeniopterus.mp4
#   start=8.500, end=8.567, mid=8.533
#
# Detection 213 | Scarus taeniopterus | FEC-00071 Scarus taeniopterus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 214 | Scarus taeniopterus | FEC-00072 Scarus taeniopterus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 215 | Scarus taeniopterus | FEC-00073 Scarus taeniopterus.mp4
#   start=7.000, end=7.167, mid=7.083
#
# Detection 216 | Scarus taeniopterus | FEC-00073 Scarus taeniopterus.mp4
#   start=7.533, end=7.700, mid=7.617
#
# Detection 217 | Scarus taeniopterus | FEC-00073 Scarus taeniopterus.mp4
#   start=8.933, end=9.100, mid=9.017
#
# Detection 218 | Scarus vetula | FEC-00074 Scarus vetula.mp4
#   start=8.000, end=8.100, mid=8.050
#
# Detection 219 | Scarus vetula | FEC-00075 Scarus vetula.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 220 | Scarus vetula | FEC-00075 Scarus vetula.mp4
#   start=8.667, end=8.800, mid=8.733
#
# Detection 221 | Sparisoma aurofrenatum | FEC-00076 Sparisoma aurofrenatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 222 | Sparisoma aurofrenatum | FEC-00077 Sparisoma aurofrenatum.mp4
#   start=8.000, end=8.200, mid=8.100
#
# Detection 223 | Sparisoma aurofrenatum | FEC-00078 Sparisoma aurofrenatum.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 224 | Sparisoma aurofrenatum | FEC-00079 Sparisoma aurofrenatum.mp4
#   start=7.967, end=8.500, mid=8.233
#
# Detection 225 | Sparisoma aurofrenatum | FEC-00080 Sparisoma aurofrenatum.mp4
#   start=8.000, end=8.067, mid=8.033
#
# Detection 226 | Sparisoma aurofrenatum | FEC-00080 Sparisoma aurofrenatum.mp4
#   start=8.767, end=8.833, mid=8.800
#
# Detection 227 | Sparisoma aurofrenatum | FEC-00080 Sparisoma aurofrenatum.mp4
#   start=9.100, end=9.167, mid=9.133
#
# Detection 228 | Sparisoma rubripinne | FEC-00081 Sparisoma rubripinne.mp4
#   start=7.000, end=7.167, mid=7.083
#
# Detection 229 | Sparisoma rubripinne | FEC-00190 Sparisoma rubripinne.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 230 | Sparisoma viride | FEC-00082 Sparisoma viride.mp4
#   start=4.967, end=5.300, mid=5.133
#
# Detection 231 | Sparisoma viride | FEC-00082 Sparisoma viride.mp4
#   start=7.267, end=7.467, mid=7.367
#
# Detection 232 | Sparisoma viride | FEC-00082 Sparisoma viride.mp4
#   start=8.933, end=9.200, mid=9.067
#
# Detection 233 | Sparisoma viride | FEC-00082 Sparisoma viride.mp4
#   start=10.067, end=10.267, mid=10.167
#
# Detection 234 | Sparisoma viride | FEC-00082 Sparisoma viride.mp4
#   start=11.367, end=11.567, mid=11.467
#
# Detection 235 | Sparisoma viride | FEC-00083 Sparisoma viride.mp4
#   start=7.967, end=8.367, mid=8.167
#
# Detection 236 | Sparisoma viride | FEC-00084 Sparisoma viride.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 237 | Sparisoma viride | FEC-00084 Sparisoma viride.mp4
#   start=8.967, end=9.100, mid=9.033
#
# Detection 238 | Sparisoma viride | FEC-00085 Sparisoma viride.mp4
#   start=7.967, end=8.267, mid=8.117
#
# Detection 239 | Sphoeroides spengleri | FEC-00086 Sphoeroides spengleri.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 240 | Stegastes diencaeus | FEC-00087 Stegastes diencaeus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 241 | Stegastes diencaeus | FEC-00088 Stegastes diencaeus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 242 | Stegastes diencaeus | FEC-00089 Stegastes diencaeus.mp4
#   start=8.000, end=8.633, mid=8.317
#
# Detection 243 | Stegastes diencaeus | FEC-00090 Stegastes diencaeus.mp4
#   start=8.000, end=8.333, mid=8.167
#
# Detection 244 | Stegastes diencaeus | FEC-00090 Stegastes diencaeus.mp4
#   start=8.400, end=8.400, mid=8.400
#   [WARN] Skipping audio: invalid interval (8.400, 8.400)
#
# Detection 245 | Stegastes diencaeus | FEC-00091 Stegastes diencaeus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 246 | Stegastes partitus | FEC-00092 Stegastes partitus.mp4
#   start=8.000, end=8.200, mid=8.100
#
# Detection 247 | Stegastes partitus | FEC-00093 Stegastes partitus.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 248 | Stegastes partitus | FEC-00094 Stegastes partitus.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 249 | Stegastes partitus | FEC-00094 Stegastes partitus.mp4
#   start=8.800, end=8.933, mid=8.867
#
# Detection 250 | Stegastes partitus | FEC-00094 Stegastes partitus.mp4
#   start=9.967, end=10.133, mid=10.050
#
# Detection 251 | Stegastes partitus | FEC-00095 Stegastes partitus.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 252 | Stegastes partitus | FEC-00096 Stegastes partitus.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 253 | Stegastes planifrons | FEC-00097 Stegastes planifrons.mp4
#   start=6.433, end=6.600, mid=6.517
#
# Detection 254 | Stegastes planifrons | FEC-00097 Stegastes planifrons.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 255 | Stegastes planifrons | FEC-00097 Stegastes planifrons.mp4
#   start=9.333, end=9.467, mid=9.400
#
# Detection 256 | Stegastes planifrons | FEC-00098 Stegastes planifrons.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 257 | Stegastes planifrons | FEC-00098 Stegastes planifrons.mp4
#   start=10.233, end=10.400, mid=10.317
#
# Detection 258 | Stegastes planifrons | FEC-00099 Stegastes planifrons.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 259 | Stegastes planifrons | FEC-00100 Stegastes planifrons.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 260 | Stegastes planifrons | FEC-00100 Stegastes planifrons.mp4
#   start=8.233, end=8.400, mid=8.317
#
# Detection 261 | Stegastes planifrons | FEC-00101 Stegastes planifrons.mp4
#   start=8.000, end=8.133, mid=8.067
#
# Detection 262 | Thalassoma bifasciatum | FEC-000102 Thalassoma bifasciatum.mp4
#   start=8.000, end=8.233, mid=8.117
#
# Detection 263 | Thalassoma bifasciatum | FEC-00124 Thalassoma bifasciatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# Detection 264 | Thalassoma bifasciatum | FEC-00125 Thalassoma bifasciatum.mp4
#   start=8.000, end=8.167, mid=8.083
#
# ✓ Finished exporting all 5-second clips into species folders.

# %%
from pathlib import Path
import ffmpeg

# Directory containing species subfolders of 5s clips
ROOT = Path("/Users/wendycao/fish/fisheye/video_clips_5s")

# Crop settings
CROP_W = 1920
CROP_H = 800
CROP_X = 0
CROP_Y = 60


def crop_video(input_path: Path):
    """Crop a single 5s video clip using ffmpeg-python."""
    output_path = input_path.with_name(input_path.stem + "_cropped.mp4")

    if output_path.exists():
        print(f"  Skipping (exists): {output_path.name}")
        return

    print(f"  Cropping → {output_path.name}")

    (
        ffmpeg
        .input(str(input_path))
        .filter("crop", CROP_W, CROP_H, CROP_X, CROP_Y)
        .output(
            str(output_path),
            vcodec="libx264",
            crf=18,
            preset="fast",
            acodec="copy",  # keep audio track intact
        )
        .overwrite_output()
        .run(quiet=True)
    )


def main():
    if not ROOT.exists():
        print(f"ERROR: Folder does not exist: {ROOT}")
        return

    # Recursively find all mp4 files under video_clips_5s
    videos = list(ROOT.rglob("*.mp4"))
    print(f"Found {len(videos)} video clips under {ROOT}")

    for vid in videos:
        print(f"\nProcessing: {vid.relative_to(ROOT)}")
        try:
            crop_video(vid)
        except Exception as e:
            print(f"  ERROR: {e}")


if __name__ == "__main__":
    main()
# Out:
# Found 265 video clips under /Users/wendycao/fish/fisheye/video_clips_5s
#
# Processing: Aulostomus maculatus/FEC-00014 Aulostomus maculatus_det000.mp4
#   Cropping → FEC-00014 Aulostomus maculatus_det000_cropped.mp4
#
# Processing: Aulostomus maculatus/FEC-00015 Aulostomus maculatus_det000.mp4
#   Cropping → FEC-00015 Aulostomus maculatus_det000_cropped.mp4
#
# Processing: Aulostomus maculatus/FEC-00013 Aulostomus maculatus_det000.mp4
#   Cropping → FEC-00013 Aulostomus maculatus_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00098 Stegastes planifrons_det000.mp4
#   Cropping → FEC-00098 Stegastes planifrons_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00098 Stegastes planifrons_det001.mp4
#   Cropping → FEC-00098 Stegastes planifrons_det001_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00101 Stegastes planifrons_det000.mp4
#   Cropping → FEC-00101 Stegastes planifrons_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00099 Stegastes planifrons_det000.mp4
#   Cropping → FEC-00099 Stegastes planifrons_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00100 Stegastes planifrons_det001.mp4
#   Cropping → FEC-00100 Stegastes planifrons_det001_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00100 Stegastes planifrons_det000.mp4
#   Cropping → FEC-00100 Stegastes planifrons_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00097 Stegastes planifrons_det001.mp4
#   Cropping → FEC-00097 Stegastes planifrons_det001_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00097 Stegastes planifrons_det000.mp4
#   Cropping → FEC-00097 Stegastes planifrons_det000_cropped.mp4
#
# Processing: Stegastes planifrons/FEC-00097 Stegastes planifrons_det002.mp4
#   Cropping → FEC-00097 Stegastes planifrons_det002_cropped.mp4
#
# Processing: Lutjanus mahogoni/FEC-00120 Lutjanus mahogoni_det000.mp4
#   Cropping → FEC-00120 Lutjanus mahogoni_det000_cropped.mp4
#
# Processing: Lutjanus mahogoni/FEC-00119 Lutjanus mahogoni_det000.mp4
#   Cropping → FEC-00119 Lutjanus mahogoni_det000_cropped.mp4
#
# Processing: Lutjanus mahogoni/FEC-00122 Lutjanus mahogoni_det000.mp4
#   Cropping → FEC-00122 Lutjanus mahogoni_det000_cropped.mp4
#
#
# Processing: Scarus taeniopterus/FEC-00073 Scarus taeniopterus_det002.mp4
#   Cropping → FEC-00073 Scarus taeniopterus_det002_cropped.mp4
#
# Processing: Scarus taeniopterus/FEC-00073 Scarus taeniopterus_det001.mp4
#   Cropping → FEC-00073 Scarus taeniopterus_det001_cropped.mp4
#
# Processing: Scarus taeniopterus/FEC-00073 Scarus taeniopterus_det000.mp4
#   Cropping → FEC-00073 Scarus taeniopterus_det000_cropped.mp4
#
# Processing: Scarus taeniopterus/FEC-00072 Scarus taeniopterus_det000.mp4
#   Cropping → FEC-00072 Scarus taeniopterus_det000_cropped.mp4
#
# Processing: Haemulon flavolineatum/FEC-00038 Haemulon flavolineatum_det000.mp4
#   Cropping → FEC-00038 Haemulon flavolineatum_det000_cropped.mp4
#
# Processing: Haemulon flavolineatum/FEC-00123 Haemulon flavolineatum_det000.mp4
#   Cropping → FEC-00123 Haemulon flavolineatum_det000_cropped.mp4
#
# Processing: Hypoplectrus chlorurus/FEC-00049 Hypoplectrus chlorurus_det000.mp4
#   Cropping → FEC-00049 Hypoplectrus chlorurus_det000_cropped.mp4
#
# Processing: Hypoplectrus chlorurus/FEC-00049 Hypoplectrus chlorurus_det001.mp4
#   Cropping → FEC-00049 Hypoplectrus chlorurus_det001_cropped.mp4
#
# Processing: Hypoplectrus chlorurus/FEC-00134 Hypoplectrus chlorurus_det000.mp4
#   Cropping → FEC-00134 Hypoplectrus chlorurus_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00020 Azurina multilineata_det001.mp4
#   Cropping → FEC-00020 Azurina multilineata_det001_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00020 Azurina multilineata_det000.mp4
#   Cropping → FEC-00020 Azurina multilineata_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det001.mp4
#   Cropping → FEC-00023 Azurina multilineata_det001_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det000.mp4
#   Cropping → FEC-00023 Azurina multilineata_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det002.mp4
#   Cropping → FEC-00023 Azurina multilineata_det002_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det003.mp4
#   Cropping → FEC-00023 Azurina multilineata_det003_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det004.mp4
#   Cropping → FEC-00023 Azurina multilineata_det004_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00023 Azurina multilineata_det005.mp4
#   Cropping → FEC-00023 Azurina multilineata_det005_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00022 Azurina multilineata_det000.mp4
#   Cropping → FEC-00022 Azurina multilineata_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00019 Azurina multilineata_det000.mp4
#   Cropping → FEC-00019 Azurina multilineata_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00021 Azurina multilineata_det000.mp4
#   Cropping → FEC-00021 Azurina multilineata_det000_cropped.mp4
#
# Processing: Azurina multilineata/FEC-00021 Azurina multilineata_det001.mp4
#   Cropping → FEC-00021 Azurina multilineata_det001_cropped.mp4
#
# Processing: Cephalopholis fulva/FEC-00133 Cephalopholis fulva_det000.mp4
#   Cropping → FEC-00133 Cephalopholis fulva_det000_cropped.mp4
#
# Processing: Cephalopholis fulva/FEC-00031 Cephalopholis fulva_det000.mp4
#   Cropping → FEC-00031 Cephalopholis fulva_det000_cropped.mp4
#
# Processing: Halichoeres maculipinna/FEC-00172 Halichoeres maculipinna_det003.mp4
#   Cropping → FEC-00172 Halichoeres maculipinna_det003_cropped.mp4
#
# Processing: Halichoeres maculipinna/FEC-00172 Halichoeres maculipinna_
heteropriacanthus cruentatus/FEC-00047 Heteropriacanthus cruentatus_det000.mp4
#   Cropping → FEC-00047 Heteropriacanthus cruentatus_det000_cropped.mp4
#
# Processing: Heteropriacanthus cruentatus/FEC-00047 Heteropriacanthus cruentatus_det001.mp4
#   Cropping → FEC-00047 Heteropriacanthus cruentatus_det001_cropped.mp4
#
# Processing: Heteropriacanthus cruentatus/FEC-00048 Heteropriacanthus cruentatus_det000.mp4
#   Cropping → FEC-00048 Heteropriacanthus cruentatus_det000_cropped.mp4
#
# Processing: Heteropriacanthus cruentatus/FEC-00047 Heteropriacanthus cruentatus_det002.mp4
#   Cropping → FEC-00047 Heteropriacanthus cruentatus_det002_cropped.mp4
#
# Processing: Heteropriacanthus cruentatus/FEC-00046 Heteropriacanthus cruentatus_det000.mp4
#   Cropping → FEC-00046 Heteropriacanthus cruentatus_det000_cropped.mp4
#
# Processing: Kyphosus bigibbus/FEC-00051 Kyphosus bigibbus_det000.mp4
#   Cropping → FEC-00051 Kyphosus bigibbus_det000_cropped.mp4
#
# Processing: Kyphosus bigibbus/FEC-00050 Kyphosus bigibbus_det000.mp4
#   Cropping → FEC-00050 Kyphosus bigibbus_det000_cropped.mp4
#
# Processing: Kyphosus bigibbus/FEC-00189 Kyphosus bigibbus_det000.mp4
#   Cropping → FEC-00189 Kyphosus bigibbus_det000_cropped.mp4
#
# Processing: Brachygenys chrysargyrea/FEC-00024 Brachygenys chrysargyrea_det000.mp4
#   Cropping → FEC-00024 Brachygenys chrysargyrea_det000_cropped.mp4
#
# Processing: Brachygenys chrysargyrea/FEC-00024 Brachygenys chrysargyrea_det001.mp4
#   Cropping → FEC-00024 Brachygenys chrysargyrea_det001_cropped.mp4
#
# Processing: Brachygenys chrysargyrea/FEC-00024 Brachygenys chrysargyrea_det002.mp4
#   Cropping → FEC-00024 Brachygenys chrysargyrea_det002_cropped.mp4
#
# Processing: Pempheris schomburgkii/FEC-00183 Pempheris schomburgkii_det000.mp4
#   Cropping → FEC-00183 Pempheris schomburgkii_det000_cropped.mp4
#
# Processing: Pempheris schomburgkii/FEC-00184 Pempheris schomburgkii_det001.mp4
#   Cropping → FEC-00184 Pempheris schomburgkii_det001_cropped.mp4
#
# Processing: Pempheris schomburgkii/FEC-00184 Pempheris schomburgkii_det000.mp4
#   Cropping → FEC-00184 Pempheris schomburgkii_det000_cropped.mp4
#
# Processing: Mulloidichthys martinicus/FEC-00058 Mulloidichthys martinicus_det000.mp4
#   Cropping → FEC-00058 Mulloidichthys martinicus_det000_cropped.mp4
#
# Processing: Mulloidichthys martinicus/FEC-00130 Mulloidichthys martinicus_det000.mp4
#   Cropping → FEC-00130 Mulloidichthys martinicus_det000_cropped.mp4
#
# Processing: Eques punctatus/FEC-00037 Eques punctatus_det000.mp4
#   Cropping → FEC-00037 Eques punctatus_det000_cropped.mp4
#
# Processing: Acanthurus coeruleus/FEC-00009 Acanthurus coeruleus_det000.mp4
#   Cropping → FEC-00009 Acanthurus coeruleus_det000_cropped.mp4
#
# Processing: Acanthurus coeruleus/FEC-00007 Acanthurus coeruleus_det000.mp4
#   Cropping → FEC-00007 Acanthurus coeruleus_det000_cropped.mp4
#
#   Cropping → FEC-00090 Stegastes diencaeus_det000_cropped.mp4
#
# Processing: Stegastes diencaeus/FEC-00089 Stegastes diencaeus_det000.mp4
#   Cropping → FEC-00089 Stegastes diencaeus_det000_cropped.mp4
#
# Processing: Stegastes diencaeus/FEC-00087 Stegastes diencaeus_det000.mp4
#   Cropping → FEC-00087 Stegastes diencaeus_det000_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det002.mp4
#   Cropping → FEC-00108 Bodianus rufus_det002_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det003.mp4
#   Cropping → FEC-00108 Bodianus rufus_det003_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det001.mp4
#   Cropping → FEC-00108 Bodianus rufus_det001_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det000.mp4
#   Cropping → FEC-00108 Bodianus rufus_det000_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det004.mp4
#   Cropping → FEC-00108 Bodianus rufus_det004_cropped.mp4
#
# Processing: Bodianus rufus/FEC-00108 Bodianus rufus_det005.mp4
#   Cropping → FEC-00108 Bodianus rufus_det005_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00056 Microspathodon chrysurus_det000.mp4
#   Cropping → FEC-00056 Microspathodon chrysurus_det000_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00056 Microspathodon chrysurus_det001.mp4
#   Cropping → FEC-00056 Microspathodon chrysurus_det001_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00055 Microspathodon chrysurus_det000.mp4
#   Cropping → FEC-00055 Microspathodon chrysurus_det000_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00057 Microspathodon chrysurus_det000.mp4
#   Cropping → FEC-00057 Microspathodon chrysurus_det000_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00054 Microspathodon chrysurus_det001.mp4
#   Cropping → FEC-00054 Microspathodon chrysurus_det001_cropped.mp4
#
# Processing: Microspathodon chrysurus/FEC-00054 Microspathodon chrysurus_det000.mp4
#   Cropping → FEC-00054 Microspathodon chrysurus_det000_cropped.mp4
#
# Processing: Holocentrus adscensionis/FEC-00179 Holocentrus adscensionis_det001.mp4
#   Cropping → FEC-00179 Holocentrus adscensionis_det001_cropped.mp4
#
# Processing: Holocentrus adscensionis/FEC-00179 Holocentrus adscensionis_det000.mp4
#   Cropping → FEC-00179 Holocentrus adscensionis_det000_cropped.mp4
#
# Processing: Holocentrus adscensionis/FEC-00180 Holocentrus adscensionis_det000.mp4
#   Cropping → FEC-00180 Holocentrus adscensionis_det000_cropped.mp4
#
# Processing: Holocentrus adscensionis/FEC-00178 Holocentrus adscensionis_det000.mp4
#   Cropping → FEC-00178 Holocentrus adscensionis_det000_cropped.mp4
#
# Processing: Caranx ruber/FEC-00026 Caranx ruber_det000.mp4
#   Cropping → FEC-00026 Caranx ruber_det000_cropped.mp4
#
# Processing: Caranx ruber/FEC-00029 Caranx ruber_det000.mp4
#   Cropping → FEC-00029 Caranx ruber_det000_cropped.mp4
#
# Processing: Caranx ruber/FEC-00030 Caranx ruber_det001.mp4
#   Cropping → FEC-00030 Caranx ruber_det001_cropped.mp4
#
# Processing: Caranx ruber/FEC-00030 Caranx ruber_det000.mp4
#   Cropping → FEC-00030 Caranx ruber_det000_cropped.mp4
#
# Processing: Caranx ruber/FEC-00028 Caranx ruber_det000.mp4
#   Cropping → FEC-00028 Caranx ruber_det000_cropped.mp4
#
# Processing: Caranx ruber/FEC-00027 Caranx ruber_det000.mp4
#   Cropping → FEC-00027 Caranx ruber_det000_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00080 Sparisoma aurofrenatum_det000.mp4
#   Cropping → FEC-00080 Sparisoma aurofrenatum_det000_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00077 Sparisoma aurofrenatum_det000.mp4
#   Cropping → FEC-00077 Sparisoma aurofrenatum_det000_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00080 Sparisoma aurofrenatum_det001.mp4
#   Cropping → FEC-00080 Sparisoma aurofrenatum_det001_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00080 Sparisoma aurofrenatum_det002.mp4
#   Cropping → FEC-00080 Sparisoma aurofrenatum_det002_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00078 Sparisoma aurofrenatum_det000.mp4
#   Cropping → FEC-00078 Sparisoma aurofrenatum_det000_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00076 Sparisoma aurofrenatum_det000.mp4
#   Cropping → FEC-00076 Sparisoma aurofrenatum_det000_cropped.mp4
#
# Processing: Sparisoma aurofrenatum/FEC-00079 Sparisoma aurofrenatum_det000.mp4
#   Cropping → FEC-00079 Sparisoma aurofrenatum_det000_cropped.mp4
#
# Processing: Holacanthus ciliaris/FEC-00176 Holacanthus ciliaris_det000.mp4
#   Cropping → FEC-00176 Holacanthus ciliaris_det000_cropped.mp4
#
# Processing: Holacanthus ciliaris/FEC-00188 Holacanthus ciliaris_det000.mp4
#   Cropping → FEC-00188 Holacanthus ciliaris_det000_cropped.mp4
#
# Processing: Thalassoma bifasciatum/FEC-00125 Thalassoma bifasciatum_det000.mp4
#   Cropping → FEC-00125 Thalassoma bifasciatum_det000_cropped.mp4
#
# Processing: Thalassoma bifasciatum/FEC-000102 Thalassoma bifasciatum_det000.mp4
#   Cropping → FEC-000102 Thalassoma bifasciatum_det000_cropped.mp4
#
# Processing: Thalassoma bifasciatum/FEC-00124 Thalassoma bifasciatum_det000.mp4
#   Cropping → FEC-00124 Thalassoma bifasciatum_det000_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det040.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det040_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det025.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det025_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det031.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det031_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det019.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det019_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det018.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det018_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det030.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det030_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det024.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det024_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det032.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det032_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det026.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det026_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det027.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det027_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det033.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det033_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det037.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det037_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det023.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det023_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det022.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det022_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det036.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det036_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det008.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det008_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det020.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det020_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det034.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det034_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det035.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det035_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det021.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det021_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det009.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det009_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det004.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det004_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det010.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det010_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det038.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det038_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det039.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det039_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det011.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det011_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det005.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det005_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det013.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det013_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det007.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det007_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det006.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det006_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det012.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det012_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det016.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det016_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det002.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det002_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det003.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det003_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det017.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det017_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det029.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det029_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det001.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det001_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det015.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det015_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det014.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det014_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det000.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det000_cropped.mp4
#
# Processing: Halichoeres radiatus/FEC-00175 Halichoeres radiatus_det028.mp4
#   Cropping → FEC-00175 Halichoeres radiatus_det028_cropped.mp4
#
# Processing: Cephalopholis cruentata/FEC-00186 Cephalopholis cruentata_det000.mp4
#   Cropping → FEC-00186 Cephalopholis cruentata_det000_cropped.mp4
#
# Processing: Azurina cyanea/FEC-00016 Azurina cyanea_det000.mp4
#   Cropping → FEC-00016 Azurina cyanea_det000_cropped.mp4
#
# Processing: Azurina cyanea/FEC-00016 Azurina cyanea_det001.mp4
#   Cropping → FEC-00016 Azurina cyanea_det001_cropped.mp4
#
# Processing: Azurina cyanea/FEC-00018 Azurina cyanea_det000.mp4
#   Cropping → FEC-00018 Azurina cyanea_det000_cropped.mp4
#
# Processing: Azurina cyanea/FEC-00017 Azurina cyanea_det001.mp4
#   Cropping → FEC-00017 Azurina cyanea_det001_cropped.mp4
#
# Processing: Azurina cyanea/FEC-00017 Azurina cyanea_det000.mp4
#   Cropping → FEC-00017 Azurina cyanea_det000_cropped.mp4
#
# Processing: Haemulon vittatum/FEC-00114 Haemulon vittatum_det000.mp4
#   Cropping → FEC-00114 Haemulon vittatum_det000_cropped.mp4
#
# Processing: Haemulon vittatum/FEC-00113 Haemulon vittatum_det000.mp4
#   Cropping → FEC-00113 Haemulon vittatum_det000_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00052 Lactophrys triqueter_det000.mp4
#   Cropping → FEC-00052 Lactophrys triqueter_det000_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00131 Lactophrys triqueter_det000.mp4
#   Cropping → FEC-00131 Lactophrys triqueter_det000_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00132 Lactophrys triqueter_det002.mp4
#   Cropping → FEC-00132 Lactophrys triqueter_det002_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00132 Lactophrys triqueter_det003.mp4
#   Cropping → FEC-00132 Lactophrys triqueter_det003_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00132 Lactophrys triqueter_det001.mp4
#   Cropping → FEC-00132 Lactophrys triqueter_det001_cropped.mp4
#
# Processing: Lactophrys triqueter/FEC-00132 Lactophrys triqueter_det000.mp4
#   Cropping → FEC-00132 Lactophrys triqueter_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00137 Abudefduf saxatilis_det000.mp4
#   Cropping → FEC-00137 Abudefduf saxatilis_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00136 Abudefduf saxatilis_det000.mp4
#   Cropping → FEC-00136 Abudefduf saxatilis_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00139 Abudefduf saxatilis_det000.mp4
#   Cropping → FEC-00139 Abudefduf saxatilis_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00140 Abudefduf saxatilis_det000.mp4
#   Cropping → FEC-00140 Abudefduf saxatilis_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis_det001.mp4
#   Cropping → FEC-00138 Abudefduf saxatilis_det001_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis_det000.mp4
#   Cropping → FEC-00138 Abudefduf saxatilis_det000_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis_det002.mp4
#   Cropping → FEC-00138 Abudefduf saxatilis_det002_cropped.mp4
#
# Processing: Abudefduf saxatilis/FEC-00138 Abudefduf saxatilis_det003.mp4
#   Cropping → FEC-00138 Abudefduf saxatilis_det003_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00096 Stegastes partitus_det000.mp4
#   Cropping → FEC-00096 Stegastes partitus_det000_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00094 Stegastes partitus_det000.mp4
#   Cropping → FEC-00094 Stegastes partitus_det000_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00094 Stegastes partitus_det001.mp4
#   Cropping → FEC-00094 Stegastes partitus_det001_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00094 Stegastes partitus_det002.mp4
#   Cropping → FEC-00094 Stegastes partitus_det002_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00093 Stegastes partitus_det000.mp4
#   Cropping → FEC-00093 Stegastes partitus_det000_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00095 Stegastes partitus_det000.mp4
#   Cropping → FEC-00095 Stegastes partitus_det000_cropped.mp4
#
# Processing: Stegastes partitus/FEC-00092 Stegastes partitus_det000.mp4
#   Cropping → FEC-00092 Stegastes partitus_det000_cropped.mp4
#
# Processing: Sparisoma rubripinne/FEC-00190 Sparisoma rubripinne_det000.mp4
#   Cropping → FEC-00190 Sparisoma rubripinne_det000_cropped.mp4
#
# Processing: Sparisoma rubripinne/FEC-00081 Sparisoma rubripinne_det000.mp4
#   Cropping → FEC-00081 Sparisoma rubripinne_det000_cropped.mp4
#
# Processing: Lutjanus apodus/FEC-00116 Lutjanus apodus_det000.mp4
#   Cropping → FEC-00116 Lutjanus apodus_det000_cropped.mp4
#
# Processing: Lutjanus apodus/FEC-00117 Lutjanus apodus_det000.mp4
#   Cropping → FEC-00117 Lutjanus apodus_det000_cropped.mp4
#
# Processing: Lutjanus apodus/FEC-00115 Lutjanus apodus_det000.mp4
#   Cropping → FEC-00115 Lutjanus apodus_det000_cropped.mp4
#
# Processing: Lutjanus apodus/FEC-00118 Lutjanus apodus_det000.mp4
#   Cropping → FEC-00118 Lutjanus apodus_det000_cropped.mp4
#
# Processing: Lutjanus apodus/FEC-00118 Lutjanus apodus_det001.mp4
#   Cropping → FEC-00118 Lutjanus apodus_det001_cropped.mp4
#
# Processing: Clepticus parrae/FEC-00034 Clepticus parrae_det000.mp4
#   Cropping → FEC-00034 Clepticus parrae_det000_cropped.mp4
#
# Processing: Clepticus parrae/FEC-00035 Clepticus parrae_det000.mp4
#   Cropping → FEC-00035 Clepticus parrae_det000_cropped.mp4
#
# Processing: Clepticus parrae/FEC-00036 Clepticus parrae_det000.mp4
#   Cropping → FEC-00036 Clepticus parrae_det000_cropped.mp4
#
# Processing: Clepticus parrae/FEC-00032 Clepticus parrae_det000.mp4
#   Cropping → FEC-00032 Clepticus parrae_det000_cropped.mp4
#
# Processing: Clepticus parrae/FEC-00032 Clepticus parrae_det001.mp4
#   Cropping → FEC-00032 Clepticus parrae_det001_cropped.mp4
#
# Processing: Scarus iseri/FEC-00065 Scarus iseri_det000.mp4
#   Cropping → FEC-00065 Scarus iseri_det000_cropped.mp4
#
# Processing: Scarus iseri/FEC-00069 Scarus iseri_det000.mp4
#   Cropping → FEC-00069 Scarus iseri_det000_cropped.mp4
#
# Processing: Scarus iseri/FEC-00066 Scarus iseri_det001.mp4
#   Cropping → FEC-00066 Scarus iseri_det001_cropped.mp4
#
# Processing: Scarus iseri/FEC-00066 Scarus iseri_det000.mp4
#   Cropping → FEC-00066 Scarus iseri_det000_cropped.mp4
#
# Processing: Scarus iseri/FEC-00069 Scarus iseri_det001.mp4
#   Cropping → FEC-00069 Scarus iseri_det001_cropped.mp4
#
# Processing: Scarus iseri/FEC-00069 Scarus iseri_det003.mp4
#   Cropping → FEC-00069 Scarus iseri_det003_cropped.mp4
#
# Processing: Scarus iseri/FEC-00069 Scarus iseri_det002.mp4
#   Cropping → FEC-00069 Scarus iseri_det002_cropped.mp4
#
# Processing: Scarus iseri/FEC-00067 Scarus iseri_det000.mp4
#   Cropping → FEC-00067 Scarus iseri_det000_cropped.mp4
#
# Processing: Scarus iseri/FEC-00068 Scarus iseri_det000.mp4
#   Cropping → FEC-00068 Scarus iseri_det000_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00085 Sparisoma viride_det000.mp4
#   Cropping → FEC-00085 Sparisoma viride_det000_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00084 Sparisoma viride_det001.mp4
#   Cropping → FEC-00084 Sparisoma viride_det001_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00084 Sparisoma viride_det000.mp4
#   Cropping → FEC-00084 Sparisoma viride_det000_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00082 Sparisoma viride_det001.mp4
#   Cropping → FEC-00082 Sparisoma viride_det001_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00082 Sparisoma viride_det000.mp4
#   Cropping → FEC-00082 Sparisoma viride_det000_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00082 Sparisoma viride_det002.mp4
#   Cropping → FEC-00082 Sparisoma viride_det002_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00082 Sparisoma viride_det003.mp4
#   Cropping → FEC-00082 Sparisoma viride_det003_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00082 Sparisoma viride_det004.mp4
#   Cropping → FEC-00082 Sparisoma viride_det004_cropped.mp4
#
# Processing: Sparisoma viride/FEC-00083 Sparisoma viride_det000.mp4
#   Cropping → FEC-00083 Sparisoma viride_det000_cropped.mp4
#
# Processing: Acanthurus tractus/FEC-00011 Acanthurus tractus_det000.mp4
#   Cropping → FEC-00011 Acanthurus tractus_det000_cropped.mp4
#
# Processing: Acanthurus tractus/FEC-00012 Acanthurus tractus_det002.mp4
#   Cropping → FEC-00012 Acanthurus tractus_det002_cropped.mp4
#
# Processing: Acanthurus tractus/FEC-00012 Acanthurus tractus_det001.mp4
#   Cropping → FEC-00012 Acanthurus tractus_det001_cropped.mp4
#
# Processing: Acanthurus tractus/FEC-00012 Acanthurus tractus_det000.mp4
#   Cropping → FEC-00012 Acanthurus tractus_det000_cropped.mp4
